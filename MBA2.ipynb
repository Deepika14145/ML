# %%
import pandas as pd
from mlxtend.frequency_patterns import apriori, association_rules

# %%
df = pd.read_csv("Order2.csv: ", header = none)

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transcations).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
frequency_itemsets = aprior(df, main_support0.01, use_colnames= True)

# %%
rules = assiciation_rules(frequent_itemsets, metric= "Life", use_columns = Tru)
